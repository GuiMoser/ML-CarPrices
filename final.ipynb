# %% [markdown]
# ### Import Libraries

# %%
import pandas as pd
import numpy as np
from sklearn.metrics import make_scorer
from sklearn.metrics import mean_squared_error as mse
from sklearn.model_selection import train_test_split
from sklearn.model_selection import cross_validate
from sklearn.model_selection import GridSearchCV
from sklearn.linear_model import LinearRegression
from catboost import CatBoostRegressor
import lightgbm as lgb 
import category_encoders as ce
# Importando libs de plot
import seaborn as sns
import matplotlib.pyplot as plt

# %%
sns.set_style('darkgrid')
# sns.set_context('talk')
sns.set_palette('rainbow')
sns.set_context("notebook", font_scale=1.5, rc={"lines.linewidth": 2.5})

# %% [markdown]
# ### Reading Dataset

# %%
df = pd.read_csv('car_data.csv')

# %% [markdown]
# ### EDA

# %%
df.shape
# Out:
# (354369, 16)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 354369 entries, 0 to 354368
# Data columns (total 16 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   DateCrawled        354369 non-null  object
#  1   Price              354369 non-null  int64
#  2   VehicleType        316879 non-null  object
#  3   RegistrationYear   354369 non-null  int64
#  4   Gearbox            334536 non-null  object
#  5   Power              354369 non-null  int64
#  6   Model              334664 non-null  object
#  7   Mileage            354369 non-null  int64
#  8   RegistrationMonth  354369 non-null  int64
#  9   FuelType           321474 non-null  object
#  10  Brand              354369 non-null  object
#  11  NotRepaired        283215 non-null  object
#  12  DateCreated        354369 non-null  object
#  13  NumberOfPictures   354369 non-null  int64
#  14  PostalCode         354369 non-null  int64
#  15  LastSeen           354369 non-null  object
# dtypes: int64(7), object(9)
# memory usage: 43.3+ MB

# %%
df.head()
# Out:
#         DateCrawled  Price VehicleType  RegistrationYear Gearbox  Power  \
# 0  24/03/2016 11:52    480         NaN              1993  manual      0
# 1  24/03/2016 10:58  18300       coupe              2011  manual    190
# 2  14/03/2016 12:52   9800         suv              2004    auto    163
# 3  17/03/2016 16:54   1500       small              2001  manual     75
# 4  31/03/2016 17:25   3600       small              2008  manual     69
#
#    Model  Mileage  RegistrationMonth  FuelType       Brand NotRepaired  \
# 0   golf   150000                  0    petrol  volkswagen         NaN
# 1    NaN   125000                  5  gasoline        audi         yes
# 2  grand   125000                  8  gasoline        jeep         NaN
# 3   golf   150000                  6    petrol  volkswagen          no
# 4  fabia    90000                  7  gasoline       skoda          no
#
#         DateCreated  NumberOfPictures  PostalCode          LastSeen
# 0  24/03/2016 00:00                 0       70435  07/04/2016 03:16
# 1  24/03/2016 00:00                 0       66954  07/04/2016 01:46
# 2  14/03/2016 00:00                 0       90480  05/04/2016 12:47
# 3  17/03/2016 00:00                 0       91074  17/03/2016 17:40
# 4  31/03/2016 00:00                 0       60437  06/04/2016 10:17

# %%
df.describe()
# Out:
#                Price  RegistrationYear          Power        Mileage  \
# count  354369.000000     354369.000000  354369.000000  354369.000000
# mean     4416.656776       2004.234448     110.094337  128211.172535
# std      4514.158514         90.227958     189.850405   37905.341530
# min         0.000000       1000.000000       0.000000    5000.000000
# 25%      1050.000000       1999.000000      69.000000  125000.000000
# 50%      2700.000000       2003.000000     105.000000  150000.000000
# 75%      6400.000000       2008.000000     143.000000  150000.000000
# max     20000.000000       9999.000000   20000.000000  150000.000000
#
#        RegistrationMonth  NumberOfPictures     PostalCode
# count      354369.000000          354369.0  354369.000000
# mean            5.714645               0.0   50508.689087
# std             3.726421               0.0   25783.096248
# min             0.000000               0.0    1067.000000
# 25%             3.000000               0.0   30165.000000
# 50%             6.000000               0.0   49413.000000
# 75%             9.000000               0.0   71083.000000
# max            12.000000               0.0   99998.000000

# %%
df.duplicated().sum()
# Out:
# 262

# %%
df.drop_duplicates(inplace=True)

# %%
(df
 .isna()
 .sum()
 .sort_values(ascending=False)
 .reset_index()
 .rename(columns = {'index' : "Column", 0 : "Missing"})
)
# Out:
#                Column  Missing
# 0         NotRepaired    71145
# 1         VehicleType    37484
# 2            FuelType    32889
# 3             Gearbox    19830
# 4               Model    19701
# 5         DateCrawled        0
# 6               Price        0
# 7    RegistrationYear        0
# 8               Power        0
# 9             Mileage        0
# 10  RegistrationMonth        0
# 11              Brand        0
# 12        DateCreated        0
# 13   NumberOfPictures        0
# 14         PostalCode        0
# 15           LastSeen        0

# %%
df.columns = df.columns.str.lower()

# %%
df['notrepaired'] = df['notrepaired'].fillna('other')

# %%
df.dropna(inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 283875 entries, 2 to 354368
# Data columns (total 16 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   datecrawled        283875 non-null  object
#  1   price              283875 non-null  int64
#  2   vehicletype        283875 non-null  object
#  3   registrationyear   283875 non-null  int64
#  4   gearbox            283875 non-null  object
#  5   power              283875 non-null  int64
#  6   model              283875 non-null  object
#  7   mileage            283875 non-null  int64
#  8   registrationmonth  283875 non-null  int64
#  9   fueltype           283875 non-null  object
#  10  brand              283875 non-null  object
#  11  notrepaired        283875 non-null  object
#  12  datecreated        283875 non-null  object
#  13  numberofpictures   283875 non-null  int64
#  14  postalcode         283875 non-null  int64
#  15  lastseen           283875 non-null  object
# dtypes: int64(7), object(9)
# memory usage: 36.8+ MB

# %%
df.head()
# Out:
#         datecrawled  price  vehicletype  registrationyear gearbox  power  \
# 2  14/03/2016 12:52   9800          suv              2004    auto    163
# 3  17/03/2016 16:54   1500        small              2001  manual     75
# 4  31/03/2016 17:25   3600        small              2008  manual     69
# 5  04/04/2016 17:36    650        sedan              1995  manual    102
# 6  01/04/2016 20:48   2200  convertible              2004  manual    109
#
#      model  mileage  registrationmonth  fueltype       brand notrepaired  \
# 2    grand   125000                  8  gasoline        jeep       other
# 3     golf   150000                  6    petrol  volkswagen          no
# 4    fabia    90000                  7  gasoline       skoda          no
# 5      3er   150000                 10    petrol         bmw         yes
# 6  2_reihe   150000                  8    petrol     peugeot          no
#
#         datecreated  numberofpictures  postalcode          lastseen
# 2  14/03/2016 00:00                 0       90480  05/04/2016 12:47
# 3  17/03/2016 00:00                 0       91074  17/03/2016 17:40
# 4  31/03/2016 00:00                 0       60437  06/04/2016 10:17
# 5  04/04/2016 00:00                 0       33775  06/04/2016 19:17
# 6  01/04/2016 00:00                 0       67112  05/04/2016 18:18

# %%
df['price'].mean()
# Out:
# 4847.349572875385

# %%
df['price'].median()
# Out:
# 3199.0

# %%
df['numberofpictures'].value_counts()
# Out:
# numberofpictures
# 0    283875
# Name: count, dtype: int64

# %%
numeric_cols = df.select_dtypes('int64').columns
fig, axes = plt.subplots(nrows=3, ncols=3, figsize=(15, 10), constrained_layout=True)
axes = axes.flatten()

for i, col in enumerate(numeric_cols):
    sns.boxplot(data=df, y=col, ax=axes[i])
    axes[i].set_title(f'{col}')

for j in range(i + 1, len(axes)):
    fig.delaxes(axes[j])

plt.tight_layout()
# Out:
# C:\Users\mmati\AppData\Local\Temp\ipykernel_13072\1801379380.py:12: UserWarning: The figure layout has changed to tight
#   plt.tight_layout()

# %%
def detect_outliers(df):
    outliers_dict = {}
    for col in df.columns:
        q1 = df[col].quantile(0.25)
        q3 = df[col].quantile(0.75)
        iqr = q3 - q1
        lower_bound = q1 - 1.5 * iqr
        upper_bound = q3 + 1.5 * iqr
        outliers = df[(df[col] < lower_bound) | (df[col] > upper_bound)]
        outliers_dict[col] = outliers.index
    return outliers_dict

outliers = detect_outliers(df[numeric_cols])
outliers_count = {col: len(outliers[col]) for col in numeric_cols}
outliers_percent = {col: (count / len(df) * 100) for col, count in outliers_count.items()}

# %%
for col, perc in outliers_percent.items():
    print(f'{col}: {perc:.2f}% of data would be discarded when removing outliers')
# Out:
# price: 4.38% dos dados seriam descartados ao remover outliers
# registrationyear: 1.43% dos dados seriam descartados ao remover outliers
# power: 2.18% dos dados seriam descartados ao remover outliers
# mileage: 15.15% dos dados seriam descartados ao remover outliers
# registrationmonth: 0.00% dos dados seriam descartados ao remover outliers
# numberofpictures: 0.00% dos dados seriam descartados ao remover outliers
# postalcode: 0.00% dos dados seriam descartados ao remover outliers

# %%
plt.figure(figsize=(12, 6))
sns.lineplot(x='mileage', y='price', data=df);
plt.title('Mileage vs Price')
# Out:
# Text(0.5, 1.0, 'Mileage vs Price')

# %%
plt.figure(figsize=(12, 6))
sns.lineplot(x='registrationyear', y="price", data=df);
plt.title('Registration Year vs Price')
# Out:
# Text(0.5, 1.0, 'Registration Year vs Price')

# %% [markdown]
# ### Train / Validation / Test

# %%
FEATURES = ['vehicletype', 'registrationyear', 'gearbox', 'power', 'model', 'mileage', 'fueltype', 'brand', 'notrepaired']
TARGET = ['price']

CATEGORICAL_FEATURES = df[FEATURES].select_dtypes('object').columns

# %%
X_train_val, X_test, y_train_val, y_test = train_test_split(df[FEATURES], df[TARGET], test_size=0.2, random_state=42)
X_train, X_val, y_train, y_val = train_test_split(X_train_val, y_train_val, test_size=0.2, random_state=42)

# %% [markdown]
# ### Encoding

# %%
encoder = ce.CatBoostEncoder(cols=CATEGORICAL_FEATURES)
encoder.fit(X_train, y_train)

X_train = encoder.transform(X_train)
X_train_val = encoder.transform(X_train_val)
X_test = encoder.transform(X_test)
X_val = encoder.transform(X_val)

# %% [markdown]
# ### Hyperparameter Tuning

# %%
def perform_gs(model, param_grid, X, y):
    gs = GridSearchCV(model, param_grid=param_grid, cv=5, scoring='neg_root_mean_squared_error', n_jobs=-1, verbose=10)
    gs.fit(X, y)
    best_model = gs.best_estimator_
    best_params = gs.best_params_
    best_score = gs.best_score_
    return best_model, best_params, best_score

# %% [markdown]
# ### CatBoost

# %%
cb = CatBoostRegressor()
params = {
    'depth': [6, 10],
    'learning_rate': [0.1, 0.5],
    'iterations': [100, 1000],
    'l2_leaf_reg': [0.5, 1.0]
}

# %%
best_model, best_params, best_score = perform_gs(cb, params, X_train_val, y_train_val)
# Out:
# Fitting 5 folds for each of 16 candidates, totalling 80 fits
# c:\ds\venv\Lib\site-packages\sklearn\model_selection\_validation.py:540: FitFailedWarning:
# 3 fits failed out of a total of 80.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 3 fits failed with the following error:
# Traceback (most recent call last):
#   File "c:\ds\venv\Lib\site-packages\sklearn\model_selection\_validation.py", line 888, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "c:\ds\venv\Lib\site-packages\catboost\core.py", line 5827, in fit
#     return self._fit(X, y, cat_features, text_features, embedding_features, None, sample_weight, None, None, None, None, baseline,
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\ds\venv\Lib\site-packages\catboost\core.py", line 2400, in _fit
#     self._train(
#   File "c:\ds\venv\Lib\site-packages\catboost\core.py", line 1780, in _train
#     self._object._train(train_pool, test_pool, params, allow_clear_pool, init_model._object if init_model else None)
#   File "_catboost.pyx", line 4833, in _catboost._CatBoost._train
#   File "_catboost.pyx", line 4882, in _catboost._CatBoost._train
# _catboost.CatBoostError: C:/Go_Agent/pipelines/BuildMaster/catboost.git/catboost/libs/train_lib/dir_helper.cpp:20: Can't create train working dir: catboost_info
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# c:\ds\venv\Lib\site-packages\sklearn\model_selection\_search.py:1102: UserWarning: One or more of the test scores are non-finite: [           nan -1706.16811042 -1805.9188759  -1707.14845048
#  -1646.15024521 -1644.0427935  -1645.60560456 -1637.65911986
#  -1711.37752096 -1657.2744518  -1712.78816495 -1655.67253274
#  -1597.3229154  -1661.37592725 -1598.26486271 -1655.25643116]
#   warnings.warn(
# 0:	learn: 4296.4145157	total: 167ms	remaining: 2m 46s
# 1:	learn: 3996.3335266	total: 205ms	remaining: 1m 42s
# 2:	learn: 3722.1899379	total: 244ms	remaining: 1m 20s
# 3:	learn: 3484.5476663	total: 280ms	remaining: 1m 9s
# 4:	learn: 3276.6036593	total: 319ms	remaining: 1m 3s
# 5:	learn: 3093.8238838	total: 356ms	remaining: 58.9s
# 6:	learn: 2929.4865241	total: 399ms	remaining: 56.6s
# 7:	learn: 2787.9441901	total: 440ms	remaining: 54.6s
# 8:	learn: 2662.2824193	total: 476ms	remaining: 52.4s
# 9:	learn: 2551.3079276	total: 511ms	remaining: 50.6s
# 10:	learn: 2458.2523137	total: 548ms	remaining: 49.3s
# 11:	learn: 2373.4164129	total: 585ms	remaining: 48.2s
# 12:	learn: 2301.3466068	total: 628ms	remaining: 47.7s
# 13:	learn: 2238.1284307	total: 666ms	remaining: 46.9s
# 14:	learn: 2183.9735342	total: 704ms	remaining: 46.2s
# 15:	learn: 2137.2539926	total: 743ms	remaining: 45.7s
# 16:	learn: 2096.9115083	total: 791ms	remaining: 45.7s
# 17:	learn: 2059.2544126	total: 829ms	remaining: 45.2s
# 18:	learn: 2029.3520648	total: 868ms	remaining: 44.8s
# 19:	learn: 1999.8243196	total: 907ms	remaining: 44.4s
# 20:	learn: 1974.7525616	total: 945ms	remaining: 44.1s
# 21:	learn: 1953.4546781	total: 984ms	remaining: 43.7s
# 22:	learn: 1935.2438426	total: 1.02s	remaining: 43.4s
# 23:	learn: 1919.3866733	total: 1.06s	remaining: 43s
# 24:	learn: 1903.3750480	total: 1.1s	remaining: 42.9s
# 25:	learn: 1890.5560395	total: 1.14s	remaining: 42.6s
# 26:	learn: 1877.3529001	total: 1.17s	remaining: 42.3s
# 27:	learn: 1864.9706559	total: 1.21s	remaining: 42s
# 28:	learn: 1855.1322289	total: 1.24s	remaining: 41.7s
# 29:	learn: 1844.4619101	total: 1.28s	remaining: 41.4s
# 30:	learn: 1836.4760531	total: 1.32s	remaining: 41.2s
# 31:	learn: 1828.8861363	total: 1.35s	remaining: 40.9s
# 32:	learn: 1822.5402471	total: 1.39s	remaining: 40.6s
# 33:	learn: 1816.8618665	total: 1.42s	remaining: 40.4s
# 34:	learn: 1810.3279069	total: 1.46s	remaining: 40.2s
# 35:	learn: 1803.2832400	total: 1.49s	remaining: 40s
# 36:	learn: 1798.9555537	total: 1.54s	remaining: 40.1s
# 37:	learn: 1793.7707936	total: 1.58s	remaining: 40s
# 38:	learn: 1789.7136745	total: 1.62s	remaining: 39.9s
# 39:	learn: 1786.0182434	total: 1.66s	remaining: 39.8s
# 40:	learn: 1782.0092031	total: 1.7s	remaining: 39.7s
# 41:	learn: 1776.0910940	total: 1.75s	remaining: 39.9s
# 42:	learn: 1771.4967007	total: 1.9s	remaining: 42.3s
# 43:	learn: 1766.8246522	total: 1.95s	remaining: 42.3s
# 44:	learn: 1762.0735864	total: 2s	remaining: 42.4s
# 45:	learn: 1758.4652346	total: 2.05s	remaining: 42.5s
# 46:	learn: 1755.9953161	total: 2.1s	remaining: 42.6s
# 47:	learn: 1752.2025535	total: 2.16s	remaining: 42.8s
# 48:	learn: 1749.1227308	total: 2.2s	remaining: 42.8s
# 49:	learn: 1745.8012624	total: 2.25s	remaining: 42.7s
# 50:	learn: 1743.5026979	total: 2.29s	remaining: 42.6s
# 51:	learn: 1741.0158388	total: 2.33s	remaining: 42.5s
# 52:	learn: 1737.1888874	total: 2.37s	remaining: 42.4s
# 53:	learn: 1733.8643397	total: 2.41s	remaining: 42.2s
# 54:	learn: 1732.0618406	total: 2.45s	remaining: 42.1s
# 55:	learn: 1728.5487785	total: 2.49s	remaining: 42s
# 56:	learn: 1725.1747760	total: 2.53s	remaining: 41.8s
# 57:	learn: 1721.7892615	total: 2.56s	remaining: 41.7s
# 58:	learn: 1719.4427781	total: 2.6s	remaining: 41.5s
# 59:	learn: 1717.2004727	total: 2.64s	remaining: 41.4s
# 60:	learn: 1715.2727647	total: 2.69s	remaining: 41.4s
# 61:	learn: 1713.9269724	total: 2.73s	remaining: 41.2s
# 62:	learn: 1712.2946914	total: 2.76s	remaining: 41.1s
# 63:	learn: 1710.2025414	total: 2.8s	remaining: 40.9s
# 64:	learn: 1708.0736177	total: 2.83s	remaining: 40.8s
# 65:	learn: 1706.0987118	total: 2.88s	remaining: 40.7s
# 66:	learn: 1704.7719964	total: 2.93s	remaining: 40.8s
# 67:	learn: 1703.5769963	total: 2.98s	remaining: 40.8s
# 68:	learn: 1700.6905902	total: 3.03s	remaining: 40.9s
# 69:	learn: 1699.0824918	total: 3.07s	remaining: 40.8s
# 70:	learn: 1698.1019979	total: 3.11s	remaining: 40.7s
# 71:	learn: 1696.2841355	total: 3.16s	remaining: 40.7s
# 72:	learn: 1694.3942251	total: 3.21s	remaining: 40.7s
# 73:	learn: 1692.9664163	total: 3.24s	remaining: 40.6s
# 74:	learn: 1691.5211202	total: 3.28s	remaining: 40.5s
# 75:	learn: 1689.3967904	total: 3.33s	remaining: 40.5s
# 76:	learn: 1688.3824940	total: 3.37s	remaining: 40.4s
# 77:	learn: 1686.0234730	total: 3.41s	remaining: 40.4s
# 78:	learn: 1684.6488385	total: 3.45s	remaining: 40.3s
# 79:	learn: 1682.7786797	total: 3.49s	remaining: 40.1s
# 80:	learn: 1680.8255036	total: 3.53s	remaining: 40s
# 81:	learn: 1679.5079328	total: 3.57s	remaining: 39.9s
# 82:	learn: 1678.1091597	total: 3.61s	remaining: 39.9s
# 83:	learn: 1676.6448589	total: 3.65s	remaining: 39.8s
# 84:	learn: 1674.5875673	total: 3.69s	remaining: 39.7s
# 85:	learn: 1673.3960215	total: 3.73s	remaining: 39.6s
# 86:	learn: 1672.5332038	total: 3.77s	remaining: 39.6s
# 87:	learn: 1671.5662004	total: 3.81s	remaining: 39.5s
# 88:	learn: 1670.3380663	total: 3.85s	remaining: 39.4s
# 89:	learn: 1669.6457445	total: 3.89s	remaining: 39.3s
# 90:	learn: 1668.6941514	total: 3.92s	remaining: 39.2s
# 91:	learn: 1667.1794845	total: 3.96s	remaining: 39.1s
# 92:	learn: 1665.9428005	total: 4s	remaining: 39s
# 93:	learn: 1664.2821194	total: 4.03s	remaining: 38.9s
# 94:	learn: 1663.3679177	total: 4.07s	remaining: 38.8s
# 95:	learn: 1661.5845984	total: 4.11s	remaining: 38.7s
# 96:	learn: 1659.5077446	total: 4.14s	remaining: 38.5s
# 97:	learn: 1658.7496878	total: 4.17s	remaining: 38.4s
# 98:	learn: 1657.3658712	total: 4.21s	remaining: 38.3s
# 99:	learn: 1656.8252058	total: 4.25s	remaining: 38.2s
# 100:	learn: 1655.5931707	total: 4.28s	remaining: 38.1s
# 101:	learn: 1654.1185021	total: 4.32s	remaining: 38s
# 102:	learn: 1653.0463743	total: 4.36s	remaining: 37.9s
# 103:	learn: 1651.4356723	total: 4.39s	remaining: 37.8s
# 104:	learn: 1650.1943811	total: 4.43s	remaining: 37.7s
# 105:	learn: 1649.1710178	total: 4.46s	remaining: 37.6s
# 106:	learn: 1648.5927936	total: 4.5s	remaining: 37.5s
# 107:	learn: 1646.9931993	total: 4.53s	remaining: 37.4s
# 108:	learn: 1645.7618603	total: 4.57s	remaining: 37.3s
# 109:	learn: 1644.5937044	total: 4.6s	remaining: 37.2s
# 110:	learn: 1643.4456633	total: 4.63s	remaining: 37.1s
# 111:	learn: 1642.1851934	total: 4.67s	remaining: 37s
# 112:	learn: 1641.5135555	total: 4.7s	remaining: 36.9s
# 113:	learn: 1640.0574804	total: 4.74s	remaining: 36.8s
# 114:	learn: 1639.1889659	total: 4.77s	remaining: 36.7s
# 115:	learn: 1638.0299433	total: 4.81s	remaining: 36.6s
# 116:	learn: 1636.9948444	total: 4.84s	remaining: 36.5s
# 117:	learn: 1634.8472549	total: 4.88s	remaining: 36.5s
# 118:	learn: 1633.5607830	total: 4.92s	remaining: 36.4s
# 119:	learn: 1632.7655356	total: 4.95s	remaining: 36.3s
# 120:	learn: 1632.0280878	total: 4.99s	remaining: 36.2s
# 121:	learn: 1630.2161083	total: 5.02s	remaining: 36.1s
# 122:	learn: 1629.5172830	total: 5.06s	remaining: 36.1s
# 123:	learn: 1628.9191911	total: 5.09s	remaining: 36s
# 124:	learn: 1627.7281212	total: 5.13s	remaining: 35.9s
# 125:	learn: 1627.0724220	total: 5.17s	remaining: 35.9s
# 126:	learn: 1625.6421420	total: 5.21s	remaining: 35.8s
# 127:	learn: 1624.7774757	total: 5.24s	remaining: 35.7s
# 128:	learn: 1623.6052684	total: 5.28s	remaining: 35.7s
# 129:	learn: 1623.1200383	total: 5.32s	remaining: 35.6s
# 130:	learn: 1622.3611412	total: 5.35s	remaining: 35.5s
# 131:	learn: 1621.3770614	total: 5.39s	remaining: 35.4s
# 132:	learn: 1620.1498879	total: 5.42s	remaining: 35.3s
# 133:	learn: 1619.5587770	total: 5.46s	remaining: 35.3s
# 134:	learn: 1619.0076230	total: 5.49s	remaining: 35.2s
# 135:	learn: 1618.1172372	total: 5.53s	remaining: 35.1s
# 136:	learn: 1616.7949636	total: 5.56s	remaining: 35s
# 137:	learn: 1615.6054757	total: 5.6s	remaining: 35s
# 138:	learn: 1614.4111163	total: 5.63s	remaining: 34.9s
# 139:	learn: 1613.3741884	total: 5.67s	remaining: 34.8s
# 140:	learn: 1612.3040834	total: 5.7s	remaining: 34.7s
# 141:	learn: 1610.9590557	total: 5.74s	remaining: 34.7s
# 142:	learn: 1609.9965721	total: 5.77s	remaining: 34.6s
# 143:	learn: 1609.1918805	total: 5.81s	remaining: 34.5s
# 144:	learn: 1608.6645652	total: 5.84s	remaining: 34.4s
# 145:	learn: 1607.6255026	total: 5.88s	remaining: 34.4s
# 146:	learn: 1606.9843711	total: 5.92s	remaining: 34.3s
# 147:	learn: 1605.8739388	total: 5.95s	remaining: 34.3s
# 148:	learn: 1604.7071442	total: 5.99s	remaining: 34.2s
# 149:	learn: 1603.7701331	total: 6.09s	remaining: 34.5s
# 150:	learn: 1603.1314547	total: 6.14s	remaining: 34.5s
# 151:	learn: 1601.0017930	total: 6.17s	remaining: 34.5s
# 152:	learn: 1600.0675539	total: 6.21s	remaining: 34.4s
# 153:	learn: 1598.8289442	total: 6.25s	remaining: 34.3s
# 154:	learn: 1598.2699586	total: 6.28s	remaining: 34.3s
# 155:	learn: 1598.1460812	total: 6.31s	remaining: 34.1s
# 156:	learn: 1597.5338729	total: 6.34s	remaining: 34s
# 157:	learn: 1596.6571423	total: 6.38s	remaining: 34s
# 158:	learn: 1595.7653016	total: 6.41s	remaining: 33.9s
# 159:	learn: 1595.0334351	total: 6.45s	remaining: 33.9s
# 160:	learn: 1594.1369402	total: 6.48s	remaining: 33.8s
# 161:	learn: 1593.4073962	total: 6.52s	remaining: 33.7s
# 162:	learn: 1592.7527758	total: 6.56s	remaining: 33.7s
# 163:	learn: 1592.2341839	total: 6.59s	remaining: 33.6s
# 164:	learn: 1591.8117194	total: 6.63s	remaining: 33.5s
# 165:	learn: 1591.0973251	total: 6.66s	remaining: 33.5s
# 166:	learn: 1590.4098541	total: 6.7s	remaining: 33.4s
# 167:	learn: 1589.6337711	total: 6.74s	remaining: 33.4s
# 168:	learn: 1588.9285384	total: 6.77s	remaining: 33.3s
# 169:	learn: 1588.2636217	total: 6.8s	remaining: 33.2s
# 170:	learn: 1587.2616970	total: 6.84s	remaining: 33.2s
# 171:	learn: 1586.1654521	total: 6.88s	remaining: 33.1s
# 172:	learn: 1585.1944303	total: 6.91s	remaining: 33s
# 173:	learn: 1584.4823178	total: 6.95s	remaining: 33s
# 174:	learn: 1583.7715363	total: 6.98s	remaining: 32.9s
# 175:	learn: 1582.4544342	total: 7.01s	remaining: 32.8s
# 176:	learn: 1581.5296622	total: 7.05s	remaining: 32.8s
# 177:	learn: 1580.9656626	total: 7.09s	remaining: 32.7s
# 178:	learn: 1579.5034753	total: 7.12s	remaining: 32.7s
# 179:	learn: 1579.4698152	total: 7.14s	remaining: 32.5s
# 180:	learn: 1578.4291441	total: 7.17s	remaining: 32.5s
# 181:	learn: 1577.9132718	total: 7.21s	remaining: 32.4s
# 182:	learn: 1577.1666833	total: 7.25s	remaining: 32.4s
# 183:	learn: 1576.1095326	total: 7.28s	remaining: 32.3s
# 184:	learn: 1575.6055668	total: 7.32s	remaining: 32.3s
# 185:	learn: 1574.7784817	total: 7.36s	remaining: 32.2s
# 186:	learn: 1574.0189131	total: 7.39s	remaining: 32.1s
# 187:	learn: 1573.4228130	total: 7.42s	remaining: 32.1s
# 188:	learn: 1573.3939460	total: 7.44s	remaining: 31.9s
# 189:	learn: 1572.0795711	total: 7.47s	remaining: 31.9s
# 190:	learn: 1571.5446607	total: 7.51s	remaining: 31.8s
# 191:	learn: 1570.9158516	total: 7.55s	remaining: 31.8s
# 192:	learn: 1569.9970592	total: 7.58s	remaining: 31.7s
# 193:	learn: 1569.5045143	total: 7.62s	remaining: 31.6s
# 194:	learn: 1568.8144690	total: 7.65s	remaining: 31.6s
# 195:	learn: 1568.2507856	total: 7.68s	remaining: 31.5s
# 196:	learn: 1567.5479521	total: 7.72s	remaining: 31.5s
# 197:	learn: 1567.1370148	total: 7.75s	remaining: 31.4s
# 198:	learn: 1566.5235376	total: 7.79s	remaining: 31.3s
# 199:	learn: 1565.9144218	total: 7.82s	remaining: 31.3s
# 200:	learn: 1565.3066632	total: 7.86s	remaining: 31.2s
# 201:	learn: 1564.7408323	total: 7.89s	remaining: 31.2s
# 202:	learn: 1564.0121355	total: 7.92s	remaining: 31.1s
# 203:	learn: 1563.5737294	total: 7.96s	remaining: 31.1s
# 204:	learn: 1563.0163915	total: 8s	remaining: 31s
# 205:	learn: 1562.5339015	total: 8.03s	remaining: 31s
# 206:	learn: 1561.9470879	total: 8.07s	remaining: 30.9s
# 207:	learn: 1561.4945399	total: 8.1s	remaining: 30.9s
# 208:	learn: 1561.4736207	total: 8.12s	remaining: 30.7s
# 209:	learn: 1561.0051019	total: 8.15s	remaining: 30.7s
# 210:	learn: 1560.6260059	total: 8.19s	remaining: 30.6s
# 211:	learn: 1559.7184698	total: 8.22s	remaining: 30.6s
# 212:	learn: 1558.9602677	total: 8.26s	remaining: 30.5s
# 213:	learn: 1558.5062048	total: 8.3s	remaining: 30.5s
# 214:	learn: 1557.9220123	total: 8.33s	remaining: 30.4s
# 215:	learn: 1556.7762267	total: 8.37s	remaining: 30.4s
# 216:	learn: 1556.2830241	total: 8.4s	remaining: 30.3s
# 217:	learn: 1555.7706014	total: 8.44s	remaining: 30.3s
# 218:	learn: 1555.2119493	total: 8.48s	remaining: 30.2s
# 219:	learn: 1554.8323762	total: 8.51s	remaining: 30.2s
# 220:	learn: 1554.3789470	total: 8.54s	remaining: 30.1s
# 221:	learn: 1553.7148360	total: 8.58s	remaining: 30.1s
# 222:	learn: 1553.4588701	total: 8.61s	remaining: 30s
# 223:	learn: 1552.9257935	total: 8.64s	remaining: 30s
# 224:	learn: 1552.4332714	total: 8.68s	remaining: 29.9s
# 225:	learn: 1551.7354273	total: 8.71s	remaining: 29.9s
# 226:	learn: 1551.0720667	total: 8.75s	remaining: 29.8s
# 227:	learn: 1550.5434542	total: 8.78s	remaining: 29.7s
# 228:	learn: 1549.8688203	total: 8.82s	remaining: 29.7s
# 229:	learn: 1549.2379778	total: 8.86s	remaining: 29.6s
# 230:	learn: 1548.8807241	total: 8.89s	remaining: 29.6s
# 231:	learn: 1548.6075254	total: 8.93s	remaining: 29.5s
# 232:	learn: 1548.1834792	total: 8.96s	remaining: 29.5s
# 233:	learn: 1547.4814258	total: 9.04s	remaining: 29.6s
# 234:	learn: 1546.8755209	total: 9.09s	remaining: 29.6s
# 235:	learn: 1546.2575923	total: 9.12s	remaining: 29.5s
# 236:	learn: 1545.9176328	total: 9.16s	remaining: 29.5s
# 237:	learn: 1545.4728926	total: 9.19s	remaining: 29.4s
# 238:	learn: 1544.7572556	total: 9.23s	remaining: 29.4s
# 239:	learn: 1544.3721059	total: 9.26s	remaining: 29.3s
# 240:	learn: 1543.7594634	total: 9.3s	remaining: 29.3s
# 241:	learn: 1543.1109890	total: 9.34s	remaining: 29.2s
# 242:	learn: 1542.8553440	total: 9.37s	remaining: 29.2s
# 243:	learn: 1542.5288730	total: 9.4s	remaining: 29.1s
# 244:	learn: 1542.0269307	total: 9.44s	remaining: 29.1s
# 245:	learn: 1541.7297170	total: 9.47s	remaining: 29s
# 246:	learn: 1541.1029146	total: 9.51s	remaining: 29s
# 247:	learn: 1540.5697842	total: 9.54s	remaining: 28.9s
# 248:	learn: 1539.9624962	total: 9.58s	remaining: 28.9s
# 249:	learn: 1539.5155743	total: 9.61s	remaining: 28.8s
# 250:	learn: 1539.0257058	total: 9.64s	remaining: 28.8s
# 251:	learn: 1538.5401205	total: 9.68s	remaining: 28.7s
# 252:	learn: 1537.6617717	total: 9.71s	remaining: 28.7s
# 253:	learn: 1537.0814055	total: 9.75s	remaining: 28.6s
# 254:	learn: 1536.6870693	total: 9.78s	remaining: 28.6s
# 255:	learn: 1536.4948748	total: 9.82s	remaining: 28.5s
# 256:	learn: 1535.8499970	total: 9.85s	remaining: 28.5s
# 257:	learn: 1534.9427794	total: 9.89s	remaining: 28.4s
# 258:	learn: 1534.6688337	total: 9.92s	remaining: 28.4s
# 259:	learn: 1534.1813426	total: 9.95s	remaining: 28.3s
# 260:	learn: 1533.7795356	total: 9.99s	remaining: 28.3s
# 261:	learn: 1532.9870995	total: 10s	remaining: 28.2s
# 262:	learn: 1532.4460427	total: 10.1s	remaining: 28.2s
# 263:	learn: 1531.9685983	total: 10.1s	remaining: 28.2s
# 264:	learn: 1531.5161043	total: 10.1s	remaining: 28.1s
# 265:	learn: 1530.8715326	total: 10.2s	remaining: 28.1s
# 266:	learn: 1530.3534291	total: 10.2s	remaining: 28s
# 267:	learn: 1529.8297214	total: 10.2s	remaining: 28s
# 268:	learn: 1529.3381714	total: 10.3s	remaining: 27.9s
# 269:	learn: 1528.9042573	total: 10.3s	remaining: 27.9s
# 270:	learn: 1528.3001198	total: 10.3s	remaining: 27.8s
# 271:	learn: 1527.5256583	total: 10.4s	remaining: 27.8s
# 272:	learn: 1526.9982772	total: 10.4s	remaining: 27.7s
# 273:	learn: 1526.4281663	total: 10.4s	remaining: 27.7s
# 274:	learn: 1525.8229567	total: 10.5s	remaining: 27.6s
# 275:	learn: 1525.2350255	total: 10.5s	remaining: 27.6s
# 276:	learn: 1524.8366307	total: 10.6s	remaining: 27.5s
# 277:	learn: 1524.4743765	total: 10.6s	remaining: 27.5s
# 278:	learn: 1523.8390047	total: 10.6s	remaining: 27.4s
# 279:	learn: 1523.4788435	total: 10.7s	remaining: 27.4s
# 280:	learn: 1522.9855038	total: 10.7s	remaining: 27.3s
# 281:	learn: 1522.4895125	total: 10.7s	remaining: 27.3s
# 282:	learn: 1521.6281012	total: 10.8s	remaining: 27.3s
# 283:	learn: 1521.1961063	total: 10.8s	remaining: 27.2s
# 284:	learn: 1520.8839117	total: 10.8s	remaining: 27.2s
# 285:	learn: 1520.7097690	total: 10.9s	remaining: 27.1s
# 286:	learn: 1520.3541657	total: 10.9s	remaining: 27.1s
# 287:	learn: 1520.0553496	total: 10.9s	remaining: 27s
# 288:	learn: 1519.6119980	total: 11s	remaining: 27s
# 289:	learn: 1519.0389975	total: 11s	remaining: 26.9s
# 290:	learn: 1518.1964165	total: 11s	remaining: 26.9s
# 291:	learn: 1517.9977725	total: 11.1s	remaining: 26.8s
# 292:	learn: 1517.5905974	total: 11.1s	remaining: 26.8s
# 293:	learn: 1517.1171557	total: 11.1s	remaining: 26.7s
# 294:	learn: 1516.6075376	total: 11.2s	remaining: 26.7s
# 295:	learn: 1516.0736895	total: 11.2s	remaining: 26.7s
# 296:	learn: 1515.7402805	total: 11.2s	remaining: 26.6s
# 297:	learn: 1515.2518487	total: 11.3s	remaining: 26.6s
# 298:	learn: 1514.8248883	total: 11.3s	remaining: 26.5s
# 299:	learn: 1514.4139471	total: 11.4s	remaining: 26.5s
# 300:	learn: 1513.8341544	total: 11.4s	remaining: 26.4s
# 301:	learn: 1513.3021912	total: 11.4s	remaining: 26.4s
# 302:	learn: 1512.7601700	total: 11.5s	remaining: 26.4s
# 303:	learn: 1512.2947288	total: 11.5s	remaining: 26.3s
# 304:	learn: 1512.0470737	total: 11.5s	remaining: 26.3s
# 305:	learn: 1511.5834230	total: 11.6s	remaining: 26.2s
# 306:	learn: 1511.3397420	total: 11.6s	remaining: 26.2s
# 307:	learn: 1510.5692716	total: 11.6s	remaining: 26.1s
# 308:	learn: 1510.1974421	total: 11.7s	remaining: 26.1s
# 309:	learn: 1509.9087981	total: 11.7s	remaining: 26.1s
# 310:	learn: 1509.6651572	total: 11.7s	remaining: 26s
# 311:	learn: 1509.0310869	total: 11.8s	remaining: 26s
# 312:	learn: 1508.6437039	total: 11.8s	remaining: 25.9s
# 313:	learn: 1508.3444835	total: 11.8s	remaining: 25.9s
# 314:	learn: 1507.9496304	total: 11.9s	remaining: 25.8s
# 315:	learn: 1507.4655359	total: 11.9s	remaining: 25.8s
# 316:	learn: 1507.1104528	total: 11.9s	remaining: 25.7s
# 317:	learn: 1506.5760555	total: 12s	remaining: 25.7s
# 318:	learn: 1506.3451427	total: 12s	remaining: 25.6s
# 319:	learn: 1506.0209447	total: 12.1s	remaining: 25.6s
# 320:	learn: 1505.9242970	total: 12.1s	remaining: 25.6s
# 321:	learn: 1505.1084306	total: 12.1s	remaining: 25.5s
# 322:	learn: 1504.8649437	total: 12.2s	remaining: 25.5s
# 323:	learn: 1504.4691745	total: 12.2s	remaining: 25.4s
# 324:	learn: 1504.0070161	total: 12.2s	remaining: 25.4s
# 325:	learn: 1503.3362715	total: 12.3s	remaining: 25.4s
# 326:	learn: 1502.7947802	total: 12.3s	remaining: 25.3s
# 327:	learn: 1502.3695100	total: 12.3s	remaining: 25.3s
# 328:	learn: 1502.1379730	total: 12.4s	remaining: 25.2s
# 329:	learn: 1501.5850345	total: 12.4s	remaining: 25.2s
# 330:	learn: 1501.4075689	total: 12.4s	remaining: 25.1s
# 331:	learn: 1500.9525989	total: 12.5s	remaining: 25.1s
# 332:	learn: 1500.4361506	total: 12.5s	remaining: 25.1s
# 333:	learn: 1499.7513264	total: 12.5s	remaining: 25s
# 334:	learn: 1499.1802913	total: 12.6s	remaining: 25s
# 335:	learn: 1498.8285977	total: 12.6s	remaining: 24.9s
# 336:	learn: 1498.3815857	total: 12.6s	remaining: 24.9s
# 337:	learn: 1497.9528412	total: 12.7s	remaining: 24.8s
# 338:	learn: 1497.6713333	total: 12.7s	remaining: 24.8s
# 339:	learn: 1497.2589942	total: 12.7s	remaining: 24.7s
# 340:	learn: 1496.9479331	total: 12.8s	remaining: 24.7s
# 341:	learn: 1496.4852123	total: 12.8s	remaining: 24.7s
# 342:	learn: 1495.9137835	total: 12.9s	remaining: 24.6s
# 343:	learn: 1495.3452493	total: 12.9s	remaining: 24.6s
# 344:	learn: 1495.0475731	total: 12.9s	remaining: 24.5s
# 345:	learn: 1494.4898164	total: 13s	remaining: 24.5s
# 346:	learn: 1494.1794378	total: 13s	remaining: 24.5s
# 347:	learn: 1493.7266649	total: 13s	remaining: 24.4s
# 348:	learn: 1493.3858906	total: 13.1s	remaining: 24.4s
# 349:	learn: 1492.9820985	total: 13.1s	remaining: 24.3s
# 350:	learn: 1492.7013960	total: 13.1s	remaining: 24.3s
# 351:	learn: 1492.3468122	total: 13.2s	remaining: 24.3s
# 352:	learn: 1491.9935517	total: 13.2s	remaining: 24.2s
# 353:	learn: 1491.7618241	total: 13.2s	remaining: 24.2s
# 354:	learn: 1491.4265713	total: 13.3s	remaining: 24.1s
# 355:	learn: 1491.0697135	total: 13.3s	remaining: 24.1s
# 356:	learn: 1490.5255301	total: 13.4s	remaining: 24.1s
# 357:	learn: 1489.8597114	total: 13.4s	remaining: 24s
# 358:	learn: 1489.0022222	total: 13.4s	remaining: 24s
# 359:	learn: 1488.4597884	total: 13.5s	remaining: 23.9s
# 360:	learn: 1488.0205133	total: 13.5s	remaining: 23.9s
# 361:	learn: 1487.8198047	total: 13.5s	remaining: 23.8s
# 362:	learn: 1487.4998066	total: 13.6s	remaining: 23.8s
# 363:	learn: 1487.1362187	total: 13.6s	remaining: 23.8s
# 364:	learn: 1486.9300110	total: 13.6s	remaining: 23.7s
# 365:	learn: 1486.6307904	total: 13.7s	remaining: 23.7s
# 366:	learn: 1486.1738588	total: 13.7s	remaining: 23.6s
# 367:	learn: 1485.9644010	total: 13.7s	remaining: 23.6s
# 368:	learn: 1485.7534614	total: 13.8s	remaining: 23.5s
# 369:	learn: 1485.2539018	total: 13.8s	remaining: 23.5s
# 370:	learn: 1484.8374714	total: 13.8s	remaining: 23.5s
# 371:	learn: 1484.5819372	total: 13.9s	remaining: 23.4s
# 372:	learn: 1484.0976907	total: 13.9s	remaining: 23.4s
# 373:	learn: 1483.2379847	total: 13.9s	remaining: 23.3s
# 374:	learn: 1482.7678866	total: 14s	remaining: 23.3s
# 375:	learn: 1482.3617736	total: 14s	remaining: 23.3s
# 376:	learn: 1481.9800200	total: 14s	remaining: 23.2s
# 377:	learn: 1481.4313659	total: 14.1s	remaining: 23.2s
# 378:	learn: 1480.9618449	total: 14.1s	remaining: 23.1s
# 379:	learn: 1480.6809342	total: 14.2s	remaining: 23.1s
# 380:	learn: 1480.3577443	total: 14.2s	remaining: 23.1s
# 381:	learn: 1480.1055169	total: 14.2s	remaining: 23s
# 382:	learn: 1479.7534764	total: 14.3s	remaining: 23s
# 383:	learn: 1479.4415340	total: 14.3s	remaining: 22.9s
# 384:	learn: 1478.9257243	total: 14.3s	remaining: 22.9s
# 385:	learn: 1478.6051138	total: 14.4s	remaining: 22.9s
# 386:	learn: 1478.2828700	total: 14.4s	remaining: 22.8s
# 387:	learn: 1477.8834194	total: 14.4s	remaining: 22.8s
# 388:	learn: 1477.4531182	total: 14.5s	remaining: 22.7s
# 389:	learn: 1476.9976643	total: 14.5s	remaining: 22.7s
# 390:	learn: 1476.2845905	total: 14.5s	remaining: 22.6s
# 391:	learn: 1475.9619554	total: 14.6s	remaining: 22.6s
# 392:	learn: 1475.4408362	total: 14.6s	remaining: 22.6s
# 393:	learn: 1474.9647073	total: 14.6s	remaining: 22.5s
# 394:	learn: 1474.6398820	total: 14.7s	remaining: 22.5s
# 395:	learn: 1474.1325578	total: 14.7s	remaining: 22.4s
# 396:	learn: 1473.7802662	total: 14.7s	remaining: 22.4s
# 397:	learn: 1473.5208382	total: 14.8s	remaining: 22.4s
# 398:	learn: 1473.0401792	total: 14.8s	remaining: 22.3s
# 399:	learn: 1472.5024064	total: 14.8s	remaining: 22.3s
# 400:	learn: 1472.0437432	total: 14.9s	remaining: 22.2s
# 401:	learn: 1471.8001361	total: 14.9s	remaining: 22.2s
# 402:	learn: 1471.6314792	total: 15s	remaining: 22.2s
# 403:	learn: 1471.4261725	total: 15s	remaining: 22.1s
# 404:	learn: 1471.0726943	total: 15s	remaining: 22.1s
# 405:	learn: 1470.8820407	total: 15.1s	remaining: 22s
# 406:	learn: 1470.6494377	total: 15.1s	remaining: 22s
# 407:	learn: 1470.3425535	total: 15.1s	remaining: 22s
# 408:	learn: 1470.0108893	total: 15.2s	remaining: 21.9s
# 409:	learn: 1469.7790755	total: 15.2s	remaining: 21.9s
# 410:	learn: 1469.3907793	total: 15.2s	remaining: 21.8s
# 411:	learn: 1468.6349355	total: 15.3s	remaining: 21.8s
# 412:	learn: 1468.2522743	total: 15.3s	remaining: 21.8s
# 413:	learn: 1467.7300454	total: 15.3s	remaining: 21.7s
# 414:	learn: 1467.3707556	total: 15.4s	remaining: 21.7s
# 415:	learn: 1467.0615068	total: 15.4s	remaining: 21.6s
# 416:	learn: 1466.7732568	total: 15.4s	remaining: 21.6s
# 417:	learn: 1466.6239078	total: 15.5s	remaining: 21.6s
# 418:	learn: 1466.4486199	total: 15.5s	remaining: 21.5s
# 419:	learn: 1466.1112518	total: 15.6s	remaining: 21.5s
# 420:	learn: 1465.6348585	total: 15.6s	remaining: 21.4s
# 421:	learn: 1465.3735239	total: 15.6s	remaining: 21.4s
# 422:	learn: 1464.9412456	total: 15.7s	remaining: 21.3s
# 423:	learn: 1464.4847172	total: 15.7s	remaining: 21.3s
# 424:	learn: 1464.1856124	total: 15.7s	remaining: 21.3s
# 425:	learn: 1463.9085475	total: 15.8s	remaining: 21.3s
# 426:	learn: 1463.6887267	total: 15.8s	remaining: 21.2s
# 427:	learn: 1463.4105725	total: 15.9s	remaining: 21.2s
# 428:	learn: 1463.1858145	total: 15.9s	remaining: 21.2s
# 429:	learn: 1462.8160457	total: 15.9s	remaining: 21.1s
# 430:	learn: 1462.4392573	total: 16s	remaining: 21.1s
# 431:	learn: 1462.2292549	total: 16s	remaining: 21.1s
# 432:	learn: 1461.9854141	total: 16.1s	remaining: 21.1s
# 433:	learn: 1461.6516720	total: 16.1s	remaining: 21s
# 434:	learn: 1461.2496484	total: 16.2s	remaining: 21s
# 435:	learn: 1460.9397770	total: 16.2s	remaining: 21s
# 436:	learn: 1460.6902859	total: 16.2s	remaining: 20.9s
# 437:	learn: 1460.3476802	total: 16.3s	remaining: 20.9s
# 438:	learn: 1459.9710814	total: 16.3s	remaining: 20.9s
# 439:	learn: 1459.6046848	total: 16.4s	remaining: 20.8s
# 440:	learn: 1459.2424044	total: 16.4s	remaining: 20.8s
# 441:	learn: 1458.8350380	total: 16.5s	remaining: 20.8s
# 442:	learn: 1458.3562081	total: 16.5s	remaining: 20.8s
# 443:	learn: 1458.2102333	total: 16.5s	remaining: 20.7s
# 444:	learn: 1457.9142154	total: 16.6s	remaining: 20.7s
# 445:	learn: 1457.5565192	total: 16.6s	remaining: 20.7s
# 446:	learn: 1457.1886911	total: 16.7s	remaining: 20.6s
# 447:	learn: 1456.7654747	total: 16.7s	remaining: 20.6s
# 448:	learn: 1456.4177438	total: 16.8s	remaining: 20.6s
# 449:	learn: 1456.2690230	total: 16.8s	remaining: 20.5s
# 450:	learn: 1455.8832370	total: 16.9s	remaining: 20.5s
# 451:	learn: 1455.1511447	total: 16.9s	remaining: 20.5s
# 452:	learn: 1454.9651486	total: 16.9s	remaining: 20.4s
# 453:	learn: 1454.4225001	total: 17s	remaining: 20.4s
# 454:	learn: 1454.1076942	total: 17s	remaining: 20.4s
# 455:	learn: 1453.7943941	total: 17s	remaining: 20.3s
# 456:	learn: 1453.6693282	total: 17.1s	remaining: 20.3s
# 457:	learn: 1453.1537993	total: 17.1s	remaining: 20.2s
# 458:	learn: 1452.7951916	total: 17.1s	remaining: 20.2s
# 459:	learn: 1452.5673437	total: 17.2s	remaining: 20.2s
# 460:	learn: 1452.3618566	total: 17.2s	remaining: 20.1s
# 461:	learn: 1452.1300318	total: 17.2s	remaining: 20.1s
# 462:	learn: 1451.7159694	total: 17.3s	remaining: 20s
# 463:	learn: 1451.4830445	total: 17.3s	remaining: 20s
# 464:	learn: 1451.2584310	total: 17.4s	remaining: 20s
# 465:	learn: 1450.9581420	total: 17.4s	remaining: 19.9s
# 466:	learn: 1450.5182653	total: 17.4s	remaining: 19.9s
# 467:	learn: 1450.3275391	total: 17.5s	remaining: 19.8s
# 468:	learn: 1449.9179156	total: 17.5s	remaining: 19.8s
# 469:	learn: 1449.5927679	total: 17.5s	remaining: 19.8s
# 470:	learn: 1449.3617513	total: 17.6s	remaining: 19.7s
# 471:	learn: 1449.0317193	total: 17.6s	remaining: 19.7s
# 472:	learn: 1448.7901540	total: 17.6s	remaining: 19.6s
# 473:	learn: 1448.5435661	total: 17.7s	remaining: 19.6s
# 474:	learn: 1448.2081223	total: 17.7s	remaining: 19.6s
# 475:	learn: 1447.7547285	total: 17.7s	remaining: 19.5s
# 476:	learn: 1447.4874536	total: 17.8s	remaining: 19.5s
# 477:	learn: 1447.2838043	total: 17.8s	remaining: 19.4s
# 478:	learn: 1447.1894044	total: 17.8s	remaining: 19.4s
# 479:	learn: 1446.8676068	total: 17.9s	remaining: 19.4s
# 480:	learn: 1446.5951876	total: 17.9s	remaining: 19.3s
# 481:	learn: 1446.2342030	total: 18s	remaining: 19.3s
# 482:	learn: 1446.1176644	total: 18s	remaining: 19.3s
# 483:	learn: 1445.8361749	total: 18s	remaining: 19.2s
# 484:	learn: 1445.6535176	total: 18.1s	remaining: 19.2s
# 485:	learn: 1445.3887992	total: 18.1s	remaining: 19.1s
# 486:	learn: 1445.0959031	total: 18.1s	remaining: 19.1s
# 487:	learn: 1444.7864208	total: 18.2s	remaining: 19.1s
# 488:	learn: 1444.6213213	total: 18.2s	remaining: 19s
# 489:	learn: 1444.2417245	total: 18.2s	remaining: 19s
# 490:	learn: 1443.6255293	total: 18.3s	remaining: 19s
# 491:	learn: 1443.3429214	total: 18.3s	remaining: 18.9s
# 492:	learn: 1443.1322780	total: 18.3s	remaining: 18.9s
# 493:	learn: 1442.9643126	total: 18.4s	remaining: 18.8s
# 494:	learn: 1442.6343058	total: 18.4s	remaining: 18.8s
# 495:	learn: 1442.4262557	total: 18.5s	remaining: 18.8s
# 496:	learn: 1442.1768922	total: 18.5s	remaining: 18.7s
# 497:	learn: 1441.7805234	total: 18.5s	remaining: 18.7s
# 498:	learn: 1441.5321886	total: 18.6s	remaining: 18.6s
# 499:	learn: 1441.2907331	total: 18.6s	remaining: 18.6s
# 500:	learn: 1440.8593701	total: 18.6s	remaining: 18.6s
# 501:	learn: 1440.5935137	total: 18.7s	remaining: 18.5s
# 502:	learn: 1440.3843174	total: 18.7s	remaining: 18.5s
# 503:	learn: 1440.1456121	total: 18.7s	remaining: 18.4s
# 504:	learn: 1439.7288124	total: 18.8s	remaining: 18.4s
# 505:	learn: 1439.5669225	total: 18.8s	remaining: 18.4s
# 506:	learn: 1439.4309536	total: 18.8s	remaining: 18.3s
# 507:	learn: 1438.9824236	total: 18.9s	remaining: 18.3s
# 508:	learn: 1438.6695939	total: 18.9s	remaining: 18.2s
# 509:	learn: 1438.3177588	total: 18.9s	remaining: 18.2s
# 510:	learn: 1438.0485751	total: 19s	remaining: 18.2s
# 511:	learn: 1437.6992888	total: 19s	remaining: 18.1s
# 512:	learn: 1437.2827888	total: 19.1s	remaining: 18.1s
# 513:	learn: 1437.0070321	total: 19.1s	remaining: 18.1s
# 514:	learn: 1436.7430187	total: 19.1s	remaining: 18s
# 515:	learn: 1436.1403894	total: 19.2s	remaining: 18s
# 516:	learn: 1435.8624330	total: 19.2s	remaining: 17.9s
# 517:	learn: 1435.1459025	total: 19.2s	remaining: 17.9s
# 518:	learn: 1434.7301285	total: 19.3s	remaining: 17.9s
# 519:	learn: 1434.4567243	total: 19.3s	remaining: 17.8s
# 520:	learn: 1434.1599655	total: 19.4s	remaining: 17.8s
# 521:	learn: 1434.0971753	total: 19.4s	remaining: 17.8s
# 522:	learn: 1433.9428698	total: 19.4s	remaining: 17.7s
# 523:	learn: 1433.6163537	total: 19.5s	remaining: 17.7s
# 524:	learn: 1433.4205009	total: 19.5s	remaining: 17.6s
# 525:	learn: 1433.0808999	total: 19.5s	remaining: 17.6s
# 526:	learn: 1432.5872414	total: 19.6s	remaining: 17.6s
# 527:	learn: 1432.3965504	total: 19.6s	remaining: 17.5s
# 528:	learn: 1432.0224833	total: 19.6s	remaining: 17.5s
# 529:	learn: 1431.8893512	total: 19.7s	remaining: 17.5s
# 530:	learn: 1431.6604604	total: 19.8s	remaining: 17.5s
# 531:	learn: 1431.4217762	total: 19.8s	remaining: 17.4s
# 532:	learn: 1431.2911607	total: 19.8s	remaining: 17.4s
# 533:	learn: 1430.9746029	total: 19.9s	remaining: 17.3s
# 534:	learn: 1430.7607114	total: 19.9s	remaining: 17.3s
# 535:	learn: 1430.4997576	total: 19.9s	remaining: 17.3s
# 536:	learn: 1430.2705406	total: 20s	remaining: 17.2s
# 537:	learn: 1429.8687065	total: 20s	remaining: 17.2s
# 538:	learn: 1429.6505491	total: 20s	remaining: 17.1s
# 539:	learn: 1429.4630348	total: 20.1s	remaining: 17.1s
# 540:	learn: 1429.2495728	total: 20.1s	remaining: 17.1s
# 541:	learn: 1429.0466959	total: 20.2s	remaining: 17s
# 542:	learn: 1428.8657841	total: 20.2s	remaining: 17s
# 543:	learn: 1428.5112412	total: 20.2s	remaining: 17s
# 544:	learn: 1428.2734528	total: 20.3s	remaining: 16.9s
# 545:	learn: 1428.0170483	total: 20.3s	remaining: 16.9s
# 546:	learn: 1427.7782643	total: 20.3s	remaining: 16.8s
# 547:	learn: 1427.5677767	total: 20.4s	remaining: 16.8s
# 548:	learn: 1427.0577534	total: 20.4s	remaining: 16.8s
# 549:	learn: 1426.8496348	total: 20.4s	remaining: 16.7s
# 550:	learn: 1426.5990747	total: 20.5s	remaining: 16.7s
# 551:	learn: 1426.3323470	total: 20.5s	remaining: 16.7s
# 552:	learn: 1426.0835640	total: 20.6s	remaining: 16.6s
# 553:	learn: 1425.8402654	total: 20.6s	remaining: 16.6s
# 554:	learn: 1425.6575518	total: 20.6s	remaining: 16.5s
# 555:	learn: 1425.3322668	total: 20.7s	remaining: 16.5s
# 556:	learn: 1425.2234015	total: 20.7s	remaining: 16.5s
# 557:	learn: 1424.9571723	total: 20.7s	remaining: 16.4s
# 558:	learn: 1424.8686466	total: 20.8s	remaining: 16.4s
# 559:	learn: 1424.6113318	total: 20.8s	remaining: 16.3s
# 560:	learn: 1424.3733350	total: 20.8s	remaining: 16.3s
# 561:	learn: 1424.1634037	total: 20.9s	remaining: 16.3s
# 562:	learn: 1423.8858069	total: 20.9s	remaining: 16.2s
# 563:	learn: 1423.7328203	total: 20.9s	remaining: 16.2s
# 564:	learn: 1423.4738436	total: 21s	remaining: 16.1s
# 565:	learn: 1423.2925304	total: 21s	remaining: 16.1s
# 566:	learn: 1422.8974465	total: 21s	remaining: 16.1s
# 567:	learn: 1422.7754776	total: 21.1s	remaining: 16s
# 568:	learn: 1422.6307293	total: 21.1s	remaining: 16s
# 569:	learn: 1422.3231037	total: 21.2s	remaining: 16s
# 570:	learn: 1421.9885150	total: 21.2s	remaining: 15.9s
# 571:	learn: 1421.7422015	total: 21.2s	remaining: 15.9s
# 572:	learn: 1421.5019998	total: 21.3s	remaining: 15.8s
# 573:	learn: 1421.3218708	total: 21.3s	remaining: 15.8s
# 574:	learn: 1421.1772390	total: 21.3s	remaining: 15.8s
# 575:	learn: 1420.8833395	total: 21.4s	remaining: 15.7s
# 576:	learn: 1420.6875605	total: 21.4s	remaining: 15.7s
# 577:	learn: 1420.4178780	total: 21.4s	remaining: 15.7s
# 578:	learn: 1420.2568039	total: 21.5s	remaining: 15.6s
# 579:	learn: 1419.9996055	total: 21.5s	remaining: 15.6s
# 580:	learn: 1419.8773704	total: 21.5s	remaining: 15.5s
# 581:	learn: 1419.5740959	total: 21.6s	remaining: 15.5s
# 582:	learn: 1419.3984208	total: 21.6s	remaining: 15.5s
# 583:	learn: 1419.0104576	total: 21.6s	remaining: 15.4s
# 584:	learn: 1418.8842334	total: 21.7s	remaining: 15.4s
# 585:	learn: 1418.4532689	total: 21.7s	remaining: 15.3s
# 586:	learn: 1418.1959513	total: 21.8s	remaining: 15.3s
# 587:	learn: 1417.9966937	total: 21.8s	remaining: 15.3s
# 588:	learn: 1417.8005967	total: 21.8s	remaining: 15.2s
# 589:	learn: 1417.5903862	total: 21.9s	remaining: 15.2s
# 590:	learn: 1417.3822959	total: 21.9s	remaining: 15.2s
# 591:	learn: 1417.0970395	total: 21.9s	remaining: 15.1s
# 592:	learn: 1416.9686258	total: 22s	remaining: 15.1s
# 593:	learn: 1416.7709796	total: 22s	remaining: 15s
# 594:	learn: 1416.5752709	total: 22s	remaining: 15s
# 595:	learn: 1416.3007922	total: 22.1s	remaining: 15s
# 596:	learn: 1416.1442297	total: 22.1s	remaining: 14.9s
# 597:	learn: 1415.9154765	total: 22.1s	remaining: 14.9s
# 598:	learn: 1415.7656939	total: 22.2s	remaining: 14.8s
# 599:	learn: 1415.6028747	total: 22.2s	remaining: 14.8s
# 600:	learn: 1415.3794006	total: 22.3s	remaining: 14.8s
# 601:	learn: 1415.2037158	total: 22.3s	remaining: 14.7s
# 602:	learn: 1414.9971421	total: 22.4s	remaining: 14.8s
# 603:	learn: 1414.7531289	total: 22.5s	remaining: 14.7s
# 604:	learn: 1414.5100381	total: 22.5s	remaining: 14.7s
# 605:	learn: 1414.4123299	total: 22.5s	remaining: 14.6s
# 606:	learn: 1413.9679514	total: 22.6s	remaining: 14.6s
# 607:	learn: 1413.5565175	total: 22.6s	remaining: 14.6s
# 608:	learn: 1413.3401915	total: 22.6s	remaining: 14.5s
# 609:	learn: 1413.1353558	total: 22.7s	remaining: 14.5s
# 610:	learn: 1412.9413499	total: 22.7s	remaining: 14.4s
# 611:	learn: 1412.4871493	total: 22.7s	remaining: 14.4s
# 612:	learn: 1412.2307305	total: 22.8s	remaining: 14.4s
# 613:	learn: 1411.8845611	total: 22.8s	remaining: 14.3s
# 614:	learn: 1411.7403891	total: 22.8s	remaining: 14.3s
# 615:	learn: 1411.5989781	total: 22.9s	remaining: 14.3s
# 616:	learn: 1411.3120455	total: 22.9s	remaining: 14.2s
# 617:	learn: 1410.9915519	total: 22.9s	remaining: 14.2s
# 618:	learn: 1410.6345541	total: 23s	remaining: 14.1s
# 619:	learn: 1410.4867360	total: 23s	remaining: 14.1s
# 620:	learn: 1410.3297897	total: 23s	remaining: 14.1s
# 621:	learn: 1410.1678813	total: 23.1s	remaining: 14s
# 622:	learn: 1409.9959415	total: 23.1s	remaining: 14s
# 623:	learn: 1409.5302733	total: 23.2s	remaining: 14s
# 624:	learn: 1409.2567341	total: 23.2s	remaining: 13.9s
# 625:	learn: 1408.9536768	total: 23.2s	remaining: 13.9s
# 626:	learn: 1408.8255159	total: 23.3s	remaining: 13.8s
# 627:	learn: 1408.6171606	total: 23.3s	remaining: 13.8s
# 628:	learn: 1408.3947578	total: 23.3s	remaining: 13.8s
# 629:	learn: 1408.2542762	total: 23.4s	remaining: 13.7s
# 630:	learn: 1408.0130094	total: 23.4s	remaining: 13.7s
# 631:	learn: 1407.8882404	total: 23.4s	remaining: 13.7s
# 632:	learn: 1407.6998669	total: 23.5s	remaining: 13.6s
# 633:	learn: 1407.4661578	total: 23.5s	remaining: 13.6s
# 634:	learn: 1407.2707149	total: 23.5s	remaining: 13.5s
# 635:	learn: 1407.0245265	total: 23.6s	remaining: 13.5s
# 636:	learn: 1406.8448559	total: 23.6s	remaining: 13.5s
# 637:	learn: 1406.6283355	total: 23.6s	remaining: 13.4s
# 638:	learn: 1406.3881210	total: 23.7s	remaining: 13.4s
# 639:	learn: 1406.1914418	total: 23.7s	remaining: 13.3s
# 640:	learn: 1405.9809620	total: 23.7s	remaining: 13.3s
# 641:	learn: 1405.5753450	total: 23.8s	remaining: 13.3s
# 642:	learn: 1405.4629300	total: 23.8s	remaining: 13.2s
# 643:	learn: 1405.2686699	total: 23.8s	remaining: 13.2s
# 644:	learn: 1405.0879025	total: 23.9s	remaining: 13.1s
# 645:	learn: 1404.9358606	total: 23.9s	remaining: 13.1s
# 646:	learn: 1404.5606331	total: 23.9s	remaining: 13.1s
# 647:	learn: 1404.4086863	total: 24s	remaining: 13s
# 648:	learn: 1404.2055778	total: 24s	remaining: 13s
# 649:	learn: 1404.0067097	total: 24.1s	remaining: 13s
# 650:	learn: 1403.9006376	total: 24.1s	remaining: 12.9s
# 651:	learn: 1403.7956287	total: 24.1s	remaining: 12.9s
# 652:	learn: 1403.7044748	total: 24.2s	remaining: 12.8s
# 653:	learn: 1403.5368891	total: 24.2s	remaining: 12.8s
# 654:	learn: 1403.4031295	total: 24.2s	remaining: 12.8s
# 655:	learn: 1403.2838766	total: 24.3s	remaining: 12.7s
# 656:	learn: 1403.1439656	total: 24.3s	remaining: 12.7s
# 657:	learn: 1402.9148718	total: 24.3s	remaining: 12.7s
# 658:	learn: 1402.4131043	total: 24.4s	remaining: 12.6s
# 659:	learn: 1402.1674886	total: 24.4s	remaining: 12.6s
# 660:	learn: 1402.0202396	total: 24.4s	remaining: 12.5s
# 661:	learn: 1401.9005993	total: 24.5s	remaining: 12.5s
# 662:	learn: 1401.6930527	total: 24.5s	remaining: 12.5s
# 663:	learn: 1401.4989352	total: 24.5s	remaining: 12.4s
# 664:	learn: 1401.2705001	total: 24.6s	remaining: 12.4s
# 665:	learn: 1400.9513731	total: 24.6s	remaining: 12.3s
# 666:	learn: 1400.7790872	total: 24.7s	remaining: 12.3s
# 667:	learn: 1400.4727995	total: 24.7s	remaining: 12.3s
# 668:	learn: 1400.3553169	total: 24.7s	remaining: 12.2s
# 669:	learn: 1400.0171600	total: 24.8s	remaining: 12.2s
# 670:	learn: 1399.8062066	total: 24.8s	remaining: 12.2s
# 671:	learn: 1399.4483813	total: 24.8s	remaining: 12.1s
# 672:	learn: 1399.3231923	total: 24.9s	remaining: 12.1s
# 673:	learn: 1399.1191705	total: 24.9s	remaining: 12s
# 674:	learn: 1398.8334155	total: 24.9s	remaining: 12s
# 675:	learn: 1398.6637270	total: 25s	remaining: 12s
# 676:	learn: 1398.2374717	total: 25s	remaining: 11.9s
# 677:	learn: 1398.0590417	total: 25s	remaining: 11.9s
# 678:	learn: 1397.9661953	total: 25.1s	remaining: 11.9s
# 679:	learn: 1397.8353459	total: 25.1s	remaining: 11.8s
# 680:	learn: 1397.6706923	total: 25.1s	remaining: 11.8s
# 681:	learn: 1397.4396970	total: 25.2s	remaining: 11.7s
# 682:	learn: 1397.2918634	total: 25.2s	remaining: 11.7s
# 683:	learn: 1397.2149967	total: 25.3s	remaining: 11.7s
# 684:	learn: 1397.0598334	total: 25.3s	remaining: 11.6s
# 685:	learn: 1396.7654108	total: 25.3s	remaining: 11.6s
# 686:	learn: 1396.4820732	total: 25.4s	remaining: 11.6s
# 687:	learn: 1396.2853373	total: 25.4s	remaining: 11.5s
# 688:	learn: 1396.1146837	total: 25.4s	remaining: 11.5s
# 689:	learn: 1396.0185289	total: 25.5s	remaining: 11.4s
# 690:	learn: 1395.6518701	total: 25.5s	remaining: 11.4s
# 691:	learn: 1395.3126352	total: 25.5s	remaining: 11.4s
# 692:	learn: 1395.0030065	total: 25.6s	remaining: 11.3s
# 693:	learn: 1394.9065316	total: 25.6s	remaining: 11.3s
# 694:	learn: 1394.7535078	total: 25.7s	remaining: 11.3s
# 695:	learn: 1394.5739972	total: 25.7s	remaining: 11.2s
# 696:	learn: 1394.3671976	total: 25.7s	remaining: 11.2s
# 697:	learn: 1394.1777738	total: 25.8s	remaining: 11.1s
# 698:	learn: 1394.0427213	total: 25.8s	remaining: 11.1s
# 699:	learn: 1393.8848440	total: 25.8s	remaining: 11.1s
# 700:	learn: 1393.5500809	total: 25.9s	remaining: 11s
# 701:	learn: 1393.2242669	total: 25.9s	remaining: 11s
# 702:	learn: 1393.0583124	total: 25.9s	remaining: 11s
# 703:	learn: 1392.8081903	total: 26s	remaining: 10.9s
# 704:	learn: 1392.5876606	total: 26s	remaining: 10.9s
# 705:	learn: 1392.4727558	total: 26s	remaining: 10.8s
# 706:	learn: 1392.3299643	total: 26.1s	remaining: 10.8s
# 707:	learn: 1392.1810397	total: 26.1s	remaining: 10.8s
# 708:	learn: 1391.9906925	total: 26.1s	remaining: 10.7s
# 709:	learn: 1391.7668163	total: 26.2s	remaining: 10.7s
# 710:	learn: 1391.6105612	total: 26.2s	remaining: 10.7s
# 711:	learn: 1391.4275620	total: 26.3s	remaining: 10.6s
# 712:	learn: 1391.1887805	total: 26.3s	remaining: 10.6s
# 713:	learn: 1391.0518929	total: 26.3s	remaining: 10.5s
# 714:	learn: 1390.7807897	total: 26.4s	remaining: 10.5s
# 715:	learn: 1390.6151090	total: 26.4s	remaining: 10.5s
# 716:	learn: 1390.3710719	total: 26.4s	remaining: 10.4s
# 717:	learn: 1390.1570020	total: 26.5s	remaining: 10.4s
# 718:	learn: 1389.9764164	total: 26.5s	remaining: 10.4s
# 719:	learn: 1389.6096927	total: 26.5s	remaining: 10.3s
# 720:	learn: 1389.3320244	total: 26.6s	remaining: 10.3s
# 721:	learn: 1389.1842006	total: 26.6s	remaining: 10.2s
# 722:	learn: 1388.9831959	total: 26.7s	remaining: 10.2s
# 723:	learn: 1388.8958588	total: 26.7s	remaining: 10.2s
# 724:	learn: 1388.7102591	total: 26.7s	remaining: 10.1s
# 725:	learn: 1388.5843630	total: 26.8s	remaining: 10.1s
# 726:	learn: 1388.5299236	total: 26.8s	remaining: 10.1s
# 727:	learn: 1388.3533505	total: 26.8s	remaining: 10s
# 728:	learn: 1388.1844177	total: 26.9s	remaining: 9.98s
# 729:	learn: 1388.0218513	total: 26.9s	remaining: 9.95s
# 730:	learn: 1387.8990920	total: 26.9s	remaining: 9.91s
# 731:	learn: 1387.7135239	total: 27s	remaining: 9.87s
# 732:	learn: 1387.4451058	total: 27s	remaining: 9.84s
# 733:	learn: 1387.1239254	total: 27s	remaining: 9.8s
# 734:	learn: 1386.9121448	total: 27.1s	remaining: 9.76s
# 735:	learn: 1386.6737302	total: 27.1s	remaining: 9.72s
# 736:	learn: 1386.5422726	total: 27.1s	remaining: 9.69s
# 737:	learn: 1386.3686986	total: 27.2s	remaining: 9.65s
# 738:	learn: 1386.0690634	total: 27.2s	remaining: 9.61s
# 739:	learn: 1385.8979660	total: 27.2s	remaining: 9.57s
# 740:	learn: 1385.6997430	total: 27.3s	remaining: 9.53s
# 741:	learn: 1385.5195146	total: 27.3s	remaining: 9.49s
# 742:	learn: 1385.4127961	total: 27.3s	remaining: 9.46s
# 743:	learn: 1385.1804009	total: 27.4s	remaining: 9.42s
# 744:	learn: 1384.9144517	total: 27.4s	remaining: 9.38s
# 745:	learn: 1384.7537437	total: 27.5s	remaining: 9.35s
# 746:	learn: 1384.6506479	total: 27.5s	remaining: 9.31s
# 747:	learn: 1384.5211636	total: 27.5s	remaining: 9.27s
# 748:	learn: 1384.3823032	total: 27.6s	remaining: 9.23s
# 749:	learn: 1384.1113620	total: 27.6s	remaining: 9.2s
# 750:	learn: 1383.8783036	total: 27.6s	remaining: 9.16s
# 751:	learn: 1383.5476666	total: 27.7s	remaining: 9.12s
# 752:	learn: 1383.3317523	total: 27.7s	remaining: 9.08s
# 753:	learn: 1383.1628885	total: 27.7s	remaining: 9.04s
# 754:	learn: 1382.7558401	total: 27.8s	remaining: 9.01s
# 755:	learn: 1382.6135802	total: 27.8s	remaining: 8.97s
# 756:	learn: 1382.3068896	total: 27.8s	remaining: 8.93s
# 757:	learn: 1382.1361888	total: 27.9s	remaining: 8.9s
# 758:	learn: 1381.9359925	total: 27.9s	remaining: 8.86s
# 759:	learn: 1381.7670098	total: 27.9s	remaining: 8.82s
# 760:	learn: 1381.5695043	total: 28s	remaining: 8.79s
# 761:	learn: 1381.3012235	total: 28s	remaining: 8.75s
# 762:	learn: 1381.1721838	total: 28s	remaining: 8.71s
# 763:	learn: 1381.0690399	total: 28.1s	remaining: 8.67s
# 764:	learn: 1380.8764101	total: 28.1s	remaining: 8.64s
# 765:	learn: 1380.6642899	total: 28.1s	remaining: 8.6s
# 766:	learn: 1380.4201253	total: 28.2s	remaining: 8.56s
# 767:	learn: 1380.3084756	total: 28.2s	remaining: 8.52s
# 768:	learn: 1379.8690971	total: 28.3s	remaining: 8.49s
# 769:	learn: 1379.7278189	total: 28.3s	remaining: 8.45s
# 770:	learn: 1379.5727968	total: 28.3s	remaining: 8.41s
# 771:	learn: 1379.4396471	total: 28.4s	remaining: 8.38s
# 772:	learn: 1379.2627288	total: 28.4s	remaining: 8.34s
# 773:	learn: 1379.1426119	total: 28.4s	remaining: 8.3s
# 774:	learn: 1379.0294764	total: 28.5s	remaining: 8.27s
# 775:	learn: 1378.9237925	total: 28.5s	remaining: 8.23s
# 776:	learn: 1378.7823159	total: 28.5s	remaining: 8.19s
# 777:	learn: 1378.6115710	total: 28.6s	remaining: 8.16s
# 778:	learn: 1378.5037244	total: 28.6s	remaining: 8.12s
# 779:	learn: 1378.2848444	total: 28.7s	remaining: 8.08s
# 780:	learn: 1378.0100912	total: 28.7s	remaining: 8.04s
# 781:	learn: 1377.7945397	total: 28.7s	remaining: 8.01s
# 782:	learn: 1377.6383743	total: 28.8s	remaining: 7.97s
# 783:	learn: 1377.5093136	total: 28.8s	remaining: 7.93s
# 784:	learn: 1377.3973519	total: 28.8s	remaining: 7.89s
# 785:	learn: 1377.2351630	total: 28.9s	remaining: 7.86s
# 786:	learn: 1377.1056556	total: 28.9s	remaining: 7.82s
# 787:	learn: 1376.8510438	total: 28.9s	remaining: 7.78s
# 788:	learn: 1376.7026895	total: 29s	remaining: 7.75s
# 789:	learn: 1376.3091853	total: 29s	remaining: 7.71s
# 790:	learn: 1376.1812502	total: 29s	remaining: 7.67s
# 791:	learn: 1375.9935443	total: 29.1s	remaining: 7.63s
# 792:	learn: 1375.8348211	total: 29.1s	remaining: 7.6s
# 793:	learn: 1375.7395110	total: 29.1s	remaining: 7.56s
# 794:	learn: 1375.5107681	total: 29.2s	remaining: 7.52s
# 795:	learn: 1375.4077648	total: 29.2s	remaining: 7.49s
# 796:	learn: 1375.1913907	total: 29.2s	remaining: 7.45s
# 797:	learn: 1375.0610680	total: 29.3s	remaining: 7.41s
# 798:	learn: 1374.8686982	total: 29.3s	remaining: 7.38s
# 799:	learn: 1374.7306953	total: 29.4s	remaining: 7.34s
# 800:	learn: 1374.5896508	total: 29.4s	remaining: 7.3s
# 801:	learn: 1374.4150463	total: 29.4s	remaining: 7.27s
# 802:	learn: 1374.2923624	total: 29.5s	remaining: 7.23s
# 803:	learn: 1374.0262762	total: 29.5s	remaining: 7.19s
# 804:	learn: 1373.8862443	total: 29.5s	remaining: 7.16s
# 805:	learn: 1373.7230458	total: 29.6s	remaining: 7.12s
# 806:	learn: 1373.5879061	total: 29.6s	remaining: 7.08s
# 807:	learn: 1373.2455803	total: 29.6s	remaining: 7.04s
# 808:	learn: 1373.0428135	total: 29.7s	remaining: 7.01s
# 809:	learn: 1372.9573244	total: 29.7s	remaining: 6.97s
# 810:	learn: 1372.5564218	total: 29.8s	remaining: 6.93s
# 811:	learn: 1372.3960722	total: 29.8s	remaining: 6.91s
# 812:	learn: 1372.2333176	total: 29.9s	remaining: 6.87s
# 813:	learn: 1372.1427156	total: 29.9s	remaining: 6.83s
# 814:	learn: 1371.8597208	total: 29.9s	remaining: 6.8s
# 815:	learn: 1371.5601291	total: 30s	remaining: 6.76s
# 816:	learn: 1371.3630063	total: 30s	remaining: 6.72s
# 817:	learn: 1371.2286525	total: 30.1s	remaining: 6.69s
# 818:	learn: 1371.0879255	total: 30.1s	remaining: 6.65s
# 819:	learn: 1370.9382249	total: 30.1s	remaining: 6.61s
# 820:	learn: 1370.7697184	total: 30.2s	remaining: 6.58s
# 821:	learn: 1370.6858753	total: 30.2s	remaining: 6.54s
# 822:	learn: 1370.5208245	total: 30.2s	remaining: 6.5s
# 823:	learn: 1370.3891866	total: 30.3s	remaining: 6.46s
# 824:	learn: 1370.2454222	total: 30.3s	remaining: 6.43s
# 825:	learn: 1370.1502156	total: 30.3s	remaining: 6.39s
# 826:	learn: 1370.0386361	total: 30.4s	remaining: 6.35s
# 827:	learn: 1369.8492784	total: 30.4s	remaining: 6.32s
# 828:	learn: 1369.7584260	total: 30.4s	remaining: 6.28s
# 829:	learn: 1369.5153914	total: 30.5s	remaining: 6.24s
# 830:	learn: 1369.4072067	total: 30.5s	remaining: 6.21s
# 831:	learn: 1369.2455963	total: 30.5s	remaining: 6.17s
# 832:	learn: 1369.0400556	total: 30.6s	remaining: 6.13s
# 833:	learn: 1368.9239853	total: 30.6s	remaining: 6.09s
# 834:	learn: 1368.8051624	total: 30.7s	remaining: 6.06s
# 835:	learn: 1368.6946330	total: 30.7s	remaining: 6.02s
# 836:	learn: 1368.4902859	total: 30.7s	remaining: 5.98s
# 837:	learn: 1368.3638970	total: 30.8s	remaining: 5.95s
# 838:	learn: 1368.1942968	total: 30.8s	remaining: 5.91s
# 839:	learn: 1368.0860827	total: 30.8s	remaining: 5.87s
# 840:	learn: 1367.9359185	total: 30.9s	remaining: 5.83s
# 841:	learn: 1367.8359625	total: 30.9s	remaining: 5.8s
# 842:	learn: 1367.7612338	total: 30.9s	remaining: 5.76s
# 843:	learn: 1367.6569973	total: 31s	remaining: 5.72s
# 844:	learn: 1367.5490243	total: 31s	remaining: 5.69s
# 845:	learn: 1367.4147150	total: 31s	remaining: 5.65s
# 846:	learn: 1367.3084799	total: 31.1s	remaining: 5.61s
# 847:	learn: 1367.1497764	total: 31.1s	remaining: 5.58s
# 848:	learn: 1366.9917189	total: 31.1s	remaining: 5.54s
# 849:	learn: 1366.9013308	total: 31.2s	remaining: 5.5s
# 850:	learn: 1366.7636948	total: 31.2s	remaining: 5.46s
# 851:	learn: 1366.6824301	total: 31.2s	remaining: 5.43s
# 852:	learn: 1366.5719173	total: 31.3s	remaining: 5.39s
# 853:	learn: 1366.4729273	total: 31.3s	remaining: 5.35s
# 854:	learn: 1366.3058301	total: 31.4s	remaining: 5.32s
# 855:	learn: 1366.1388977	total: 31.4s	remaining: 5.28s
# 856:	learn: 1366.0457680	total: 31.4s	remaining: 5.24s
# 857:	learn: 1365.9037272	total: 31.5s	remaining: 5.21s
# 858:	learn: 1365.7548558	total: 31.5s	remaining: 5.17s
# 859:	learn: 1365.6027513	total: 31.5s	remaining: 5.13s
# 860:	learn: 1365.3977564	total: 31.6s	remaining: 5.09s
# 861:	learn: 1365.3064880	total: 31.6s	remaining: 5.06s
# 862:	learn: 1365.1655997	total: 31.6s	remaining: 5.02s
# 863:	learn: 1365.0302364	total: 31.7s	remaining: 4.98s
# 864:	learn: 1364.8992424	total: 31.8s	remaining: 4.96s
# 865:	learn: 1364.6471156	total: 31.8s	remaining: 4.92s
# 866:	learn: 1364.5917943	total: 31.9s	remaining: 4.89s
# 867:	learn: 1364.3785574	total: 31.9s	remaining: 4.85s
# 868:	learn: 1364.2761495	total: 31.9s	remaining: 4.81s
# 869:	learn: 1364.1327896	total: 32s	remaining: 4.78s
# 870:	learn: 1364.0375019	total: 32s	remaining: 4.74s
# 871:	learn: 1363.8674576	total: 32s	remaining: 4.7s
# 872:	learn: 1363.7201667	total: 32.1s	remaining: 4.67s
# 873:	learn: 1363.6366714	total: 32.1s	remaining: 4.63s
# 874:	learn: 1363.4952794	total: 32.2s	remaining: 4.59s
# 875:	learn: 1363.1842831	total: 32.2s	remaining: 4.56s
# 876:	learn: 1362.9328957	total: 32.2s	remaining: 4.52s
# 877:	learn: 1362.4813910	total: 32.3s	remaining: 4.48s
# 878:	learn: 1362.3080396	total: 32.3s	remaining: 4.45s
# 879:	learn: 1362.1986350	total: 32.3s	remaining: 4.41s
# 880:	learn: 1362.1326698	total: 32.4s	remaining: 4.37s
# 881:	learn: 1362.0361507	total: 32.4s	remaining: 4.33s
# 882:	learn: 1361.8302439	total: 32.4s	remaining: 4.3s
# 883:	learn: 1361.7173887	total: 32.5s	remaining: 4.26s
# 884:	learn: 1361.5233518	total: 32.5s	remaining: 4.22s
# 885:	learn: 1361.3987807	total: 32.5s	remaining: 4.19s
# 886:	learn: 1361.2344259	total: 32.6s	remaining: 4.15s
# 887:	learn: 1361.0850647	total: 32.6s	remaining: 4.11s
# 888:	learn: 1360.9559769	total: 32.7s	remaining: 4.08s
# 889:	learn: 1360.8329775	total: 32.7s	remaining: 4.04s
# 890:	learn: 1360.7134398	total: 32.7s	remaining: 4s
# 891:	learn: 1360.6056608	total: 32.8s	remaining: 3.97s
# 892:	learn: 1360.5139082	total: 32.8s	remaining: 3.93s
# 893:	learn: 1360.3680688	total: 32.8s	remaining: 3.89s
# 894:	learn: 1360.1412651	total: 32.9s	remaining: 3.86s
# 895:	learn: 1359.9904067	total: 32.9s	remaining: 3.82s
# 896:	learn: 1359.8217677	total: 32.9s	remaining: 3.78s
# 897:	learn: 1359.7071552	total: 33s	remaining: 3.75s
# 898:	learn: 1359.3996728	total: 33s	remaining: 3.71s
# 899:	learn: 1359.1550084	total: 33s	remaining: 3.67s
# 900:	learn: 1359.0403119	total: 33.1s	remaining: 3.63s
# 901:	learn: 1358.8404369	total: 33.1s	remaining: 3.6s
# 902:	learn: 1358.7354939	total: 33.2s	remaining: 3.56s
# 903:	learn: 1358.5566596	total: 33.2s	remaining: 3.52s
# 904:	learn: 1358.4948060	total: 33.2s	remaining: 3.49s
# 905:	learn: 1358.2747580	total: 33.3s	remaining: 3.45s
# 906:	learn: 1358.1585015	total: 33.3s	remaining: 3.41s
# 907:	learn: 1358.0498720	total: 33.3s	remaining: 3.38s
# 908:	learn: 1357.9353747	total: 33.4s	remaining: 3.34s
# 909:	learn: 1357.8728232	total: 33.4s	remaining: 3.3s
# 910:	learn: 1357.8157611	total: 33.4s	remaining: 3.27s
# 911:	learn: 1357.6655639	total: 33.5s	remaining: 3.23s
# 912:	learn: 1357.5218499	total: 33.5s	remaining: 3.19s
# 913:	learn: 1357.3609612	total: 33.5s	remaining: 3.15s
# 914:	learn: 1357.1700174	total: 33.6s	remaining: 3.12s
# 915:	learn: 1357.0496816	total: 33.6s	remaining: 3.08s
# 916:	learn: 1356.8277920	total: 33.6s	remaining: 3.04s
# 917:	learn: 1356.6916554	total: 33.7s	remaining: 3.01s
# 918:	learn: 1356.4962433	total: 33.7s	remaining: 2.97s
# 919:	learn: 1356.3419717	total: 33.7s	remaining: 2.93s
# 920:	learn: 1356.2061133	total: 33.8s	remaining: 2.9s
# 921:	learn: 1356.0305482	total: 33.8s	remaining: 2.86s
# 922:	learn: 1355.9473425	total: 33.9s	remaining: 2.82s
# 923:	learn: 1355.7880296	total: 33.9s	remaining: 2.79s
# 924:	learn: 1355.6898728	total: 33.9s	remaining: 2.75s
# 925:	learn: 1355.4435834	total: 34s	remaining: 2.71s
# 926:	learn: 1355.2930345	total: 34s	remaining: 2.68s
# 927:	learn: 1355.1811620	total: 34s	remaining: 2.64s
# 928:	learn: 1354.9980935	total: 34.1s	remaining: 2.6s
# 929:	learn: 1354.8830613	total: 34.1s	remaining: 2.57s
# 930:	learn: 1354.8088165	total: 34.1s	remaining: 2.53s
# 931:	learn: 1354.7554063	total: 34.2s	remaining: 2.49s
# 932:	learn: 1354.6508377	total: 34.2s	remaining: 2.46s
# 933:	learn: 1354.5639670	total: 34.2s	remaining: 2.42s
# 934:	learn: 1354.4954639	total: 34.3s	remaining: 2.38s
# 935:	learn: 1354.3729569	total: 34.3s	remaining: 2.35s
# 936:	learn: 1354.2663492	total: 34.3s	remaining: 2.31s
# 937:	learn: 1354.1618789	total: 34.4s	remaining: 2.27s
# 938:	learn: 1354.0039857	total: 34.4s	remaining: 2.23s
# 939:	learn: 1353.8510220	total: 34.5s	remaining: 2.2s
# 940:	learn: 1353.7788034	total: 34.5s	remaining: 2.16s
# 941:	learn: 1353.5645212	total: 34.5s	remaining: 2.13s
# 942:	learn: 1353.4817327	total: 34.6s	remaining: 2.09s
# 943:	learn: 1353.2038028	total: 34.6s	remaining: 2.05s
# 944:	learn: 1353.0992632	total: 34.6s	remaining: 2.02s
# 945:	learn: 1352.8763618	total: 34.7s	remaining: 1.98s
# 946:	learn: 1352.8100201	total: 34.7s	remaining: 1.94s
# 947:	learn: 1352.6908509	total: 34.7s	remaining: 1.9s
# 948:	learn: 1352.5676238	total: 34.8s	remaining: 1.87s
# 949:	learn: 1352.2705324	total: 34.8s	remaining: 1.83s
# 950:	learn: 1352.1593037	total: 34.8s	remaining: 1.79s
# 951:	learn: 1352.0829547	total: 34.9s	remaining: 1.76s
# 952:	learn: 1351.9806256	total: 34.9s	remaining: 1.72s
# 953:	learn: 1351.8818942	total: 34.9s	remaining: 1.68s
# 954:	learn: 1351.7659913	total: 35s	remaining: 1.65s
# 955:	learn: 1351.6727036	total: 35s	remaining: 1.61s
# 956:	learn: 1351.4047743	total: 35s	remaining: 1.57s
# 957:	learn: 1351.1076928	total: 35.1s	remaining: 1.54s
# 958:	learn: 1351.0325648	total: 35.1s	remaining: 1.5s
# 959:	learn: 1350.8918972	total: 35.1s	remaining: 1.46s
# 960:	learn: 1350.7794056	total: 35.2s	remaining: 1.43s
# 961:	learn: 1350.5745899	total: 35.2s	remaining: 1.39s
# 962:	learn: 1350.3744294	total: 35.2s	remaining: 1.35s
# 963:	learn: 1350.2379391	total: 35.3s	remaining: 1.32s
# 964:	learn: 1350.0802876	total: 35.3s	remaining: 1.28s
# 965:	learn: 1349.9504354	total: 35.4s	remaining: 1.24s
# 966:	learn: 1349.7580764	total: 35.4s	remaining: 1.21s
# 967:	learn: 1349.6579717	total: 35.4s	remaining: 1.17s
# 968:	learn: 1349.5136435	total: 35.5s	remaining: 1.13s
# 969:	learn: 1349.4728806	total: 35.5s	remaining: 1.1s
# 970:	learn: 1349.3827935	total: 35.5s	remaining: 1.06s
# 971:	learn: 1349.2195601	total: 35.5s	remaining: 1.02s
# 972:	learn: 1349.0660291	total: 35.6s	remaining: 987ms
# 973:	learn: 1348.8025048	total: 35.6s	remaining: 951ms
# 974:	learn: 1348.6106515	total: 35.6s	remaining: 914ms
# 975:	learn: 1348.4103585	total: 35.7s	remaining: 877ms
# 976:	learn: 1348.3679520	total: 35.7s	remaining: 841ms
# 977:	learn: 1348.1927543	total: 35.7s	remaining: 804ms
# 978:	learn: 1348.1293072	total: 35.8s	remaining: 767ms
# 979:	learn: 1348.0308813	total: 35.8s	remaining: 731ms
# 980:	learn: 1347.9512116	total: 35.8s	remaining: 694ms
# 981:	learn: 1347.6257115	total: 35.9s	remaining: 658ms
# 982:	learn: 1347.5244505	total: 35.9s	remaining: 621ms
# 983:	learn: 1347.2804853	total: 36s	remaining: 585ms
# 984:	learn: 1347.1684645	total: 36s	remaining: 548ms
# 985:	learn: 1346.9865756	total: 36s	remaining: 512ms
# 986:	learn: 1346.8698691	total: 36.1s	remaining: 475ms
# 987:	learn: 1346.7935258	total: 36.1s	remaining: 438ms
# 988:	learn: 1346.6303711	total: 36.1s	remaining: 402ms
# 989:	learn: 1346.4971909	total: 36.2s	remaining: 365ms
# 990:	learn: 1346.3935529	total: 36.2s	remaining: 329ms
# 991:	learn: 1346.2844793	total: 36.2s	remaining: 292ms
# 992:	learn: 1346.1665054	total: 36.3s	remaining: 256ms
# 993:	learn: 1346.0007224	total: 36.3s	remaining: 219ms
# 994:	learn: 1345.8627343	total: 36.4s	remaining: 183ms
# 995:	learn: 1345.7844165	total: 36.4s	remaining: 146ms
# 996:	learn: 1345.5853375	total: 36.4s	remaining: 110ms
# 997:	learn: 1345.3927672	total: 36.5s	remaining: 73.1ms
# 998:	learn: 1345.2140991	total: 36.5s	remaining: 36.5ms
# 999:	learn: 1345.1069480	total: 36.5s	remaining: 0us

# %%
print(f'Best params: {best_params}')
print(f'Best RMSE', {best_score})
# Out:
# Best params: {'depth': 10, 'iterations': 1000, 'l2_leaf_reg': 0.5, 'learning_rate': 0.1}
# Best RMSE {-1597.3229153965976}

# %% [markdown]
# ### LightGBM

# %%
lg = lgb.LGBMRegressor()
params = {
    'learning_rate': [0.01, 0.5], 
    'num_leaves': [24, 80],
    'max_depth': [5, 30],
    'n_estimators': [50, 1000],
}

# %%
best_model, best_params, best_score = perform_gs(lg, params, X_train_val, y_train_val)
# Out:
# Fitting 5 folds for each of 16 candidates, totalling 80 fits
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.001787 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 659
# [LightGBM] [Info] Number of data points in the train set: 227100, number of used features: 9
# [LightGBM] [Info] Start training from score 4849.698833
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf

# %%
print(f'Best params: {best_params}')
print(f'Best RMSE', {best_score})
# Out:
# Best params: {'learning_rate': 0.5, 'max_depth': 5, 'n_estimators': 1000, 'num_leaves': 24}
# Best RMSE {-1641.4485831756733}

# %% [markdown]
# ### Gradient Boosting

# %% [markdown]
# ### LinearRegression

# %%
lr = LinearRegression()
lr.fit(X_train_val, y_train_val)
lr_pred = lr.predict(X_val)

# %%
lr_rmse = mse(y_val, lr_pred) ** 0.5
lr_rmse
# Out:
# 2941.603165567877

# %% [markdown]
# ### CatBoost

# %%
cb = CatBoostRegressor(loss_function='RMSE', iterations=1000, depth=10, l2_leaf_reg=0.5, learning_rate=0.1)
cb.fit(X_train_val, y_train_val, verbose=100)
cb_pred = cb.predict(X_val)
# Out:
# 0:	learn: 4296.4145157	total: 42.5ms	remaining: 42.5s
# 100:	learn: 1655.5931707	total: 4.06s	remaining: 36.2s
# 200:	learn: 1565.3066632	total: 8.44s	remaining: 33.6s
# 300:	learn: 1513.8341544	total: 13.1s	remaining: 30.4s
# 400:	learn: 1472.0437432	total: 17.3s	remaining: 25.9s
# 500:	learn: 1440.8593701	total: 21.9s	remaining: 21.8s
# 600:	learn: 1415.3794006	total: 26.2s	remaining: 17.4s
# 700:	learn: 1393.5500809	total: 30.6s	remaining: 13.1s
# 800:	learn: 1374.5896508	total: 34.7s	remaining: 8.61s
# 900:	learn: 1359.0403119	total: 39.2s	remaining: 4.31s
# 999:	learn: 1345.1069480	total: 43.5s	remaining: 0us

# %%
cb_rmse = mse(y_val, cb_pred) ** 0.5
cb_rmse
# Out:
# 1348.0090043764849

# %% [markdown]
# ### LightGBM

# %%
train_data = lgb.Dataset(X_train_val, label=y_train_val)
test_data = lgb.Dataset(X_val, label=y_val, reference=train_data)

params = { 
    'objective': 'regression', 
    'metric': 'rmse', 
    'boosting_type': 'gbdt', 
    'num_leaves': 24, 
    'max_depth': 5,
    'learning_rate': 0.05, 
    'n_estimators': 1000,
} 

num_round = 100
boosting = lgb.train(params, train_data, num_round, valid_sets=[test_data], callbacks=[lgb.early_stopping(stopping_rounds=10)])
# Out:
# c:\ds\venv\Lib\site-packages\lightgbm\engine.py:204: UserWarning: Found `n_estimators` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.002513 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 659
# [LightGBM] [Info] Number of data points in the train set: 227100, number of used features: 9
# [LightGBM] [Info] Start training from score 4849.698833
# Training until validation scores don't improve for 10 rounds
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# Did not meet early stopping. Best iteration is:
# [1000]	valid_0's rmse: 1610.28

# %%
lg = lgb.LGBMRegressor(metric='rmse', num_leaves=24, max_depth=5, learning_rate=0.5, n_estimators=1000, verbose=-1)
lg.fit(X_train_val, y_train_val)
lg_pred = lg.predict(X_val)

# %%
lg_rmse = mse(y_val, lg_pred) ** 0.5
lg_rmse
# Out:
# 1404.2421579306983

# %% [markdown]
# ### Model Analysis

# %% [markdown]
# ### LinearRegression

# %%
lr = LinearRegression()
lr.fit(X_train_val, y_train_val)
lr_pred = lr.predict(X_test)

# %%
lr_rmse = mse(y_test, lr_pred) ** 0.5
lr_rmse
# Out:
# 2904.17011892264

# %% [markdown]
# ### CatBoost

# %%
# %%time

cb = CatBoostRegressor(loss_function='RMSE', iterations=1000, depth=10, l2_leaf_reg=0.5, learning_rate=0.1)
cb.fit(X_train_val, y_train_val, verbose=100)
cb_pred = cb.predict(X_test)
# Out:
# 0:	learn: 4296.4145157	total: 56.3ms	remaining: 56.3s
# 100:	learn: 1655.5931707	total: 4.57s	remaining: 40.7s
# 200:	learn: 1565.3066632	total: 8.74s	remaining: 34.7s
# 300:	learn: 1513.8341544	total: 13.1s	remaining: 30.5s
# 400:	learn: 1472.0437432	total: 17.7s	remaining: 26.5s
# 500:	learn: 1440.8593701	total: 21.9s	remaining: 21.8s
# 600:	learn: 1415.3794006	total: 25.8s	remaining: 17.1s
# 700:	learn: 1393.5500809	total: 30.5s	remaining: 13s
# 800:	learn: 1374.5896508	total: 35s	remaining: 8.7s
# 900:	learn: 1359.0403119	total: 39.3s	remaining: 4.32s
# 999:	learn: 1345.1069480	total: 43.2s	remaining: 0us
# CPU times: total: 1min 47s
# Wall time: 43.8 s

# %%
cb_rmse = mse(y_test, cb_pred) ** 0.5
cb_rmse
# Out:
# 1562.265902010746

# %%
feature_importance = cb.get_feature_importance()
features_names = df[FEATURES].columns

fig, ax = plt.subplots(figsize=(8, 4))
sns.barplot(x=feature_importance, y=features_names)
plt.title('Feature Importance')
plt.xlabel('Importance')
plt.ylabel('Features');

# %% [markdown]
# ### LightGBM

# %%
# %%time

lg = lgb.LGBMRegressor(metric='rmse', num_leaves=24, max_depth=5, learning_rate=0.5, n_estimators=1000, verbose=-1)
lg.fit(X_train_val, y_train_val)
lg_pred = lg.predict(X_test)
# Out:
# CPU times: total: 13.5 s
# Wall time: 5.18 s

# %%
lg_rmse = mse(y_test, lg_pred) ** 0.5
lg_rmse
# Out:
# 1608.193420509126

# %%
fig, ax = plt.subplots(figsize=(8, 4))
lgb.plot_importance(lg, ax=ax);

# %% [markdown]
# ## Conclusion

# %% [markdown]
# It can be concluded that even though the CatBoost model has a slightly lower RMSE than LightGBM, when analyzing and comparing the models' execution time, the best choice for this case is LightGBM.
